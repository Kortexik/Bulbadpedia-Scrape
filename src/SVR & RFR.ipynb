# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('display.width', 1000)

# %%
df = pd.read_csv('../saves/PokemonsForModel.csv')
df2 = pd.read_csv('../saves/ModelDataset.csv')

# %%
X = df2.drop('Unnamed: 0', axis=1)
y = df['Catch Rate']

# %%
lvl = pd.get_dummies(df['Levelling Rate'], dtype=float)

# %%
X = pd.concat([X, lvl], axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(X_train, y_train)
svr.get_params()
# Out:
# {'C': 1.0,
#  'cache_size': 200,
#  'coef0': 0.0,
#  'degree': 3,
#  'epsilon': 0.1,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
from sklearn.model_selection import GridSearchCV

# %%
param = {'C' : [1, 5, 10, 20, 50], 'coef0' : [0.001, 0.01,10,0.5],'gamma' : ('auto','scale')}

# %%
gs = GridSearchCV(estimator=svr, param_grid=param, verbose=3)
gs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5] END .....C=1, coef0=0.001, gamma=auto;, score=-0.201 total time=   0.0s
# [CV 2/5] END .....C=1, coef0=0.001, gamma=auto;, score=-0.285 total time=   0.0s
# [CV 3/5] END .....C=1, coef0=0.001, gamma=auto;, score=-0.215 total time=   0.0s
# [CV 4/5] END .....C=1, coef0=0.001, gamma=auto;, score=-0.171 total time=   0.1s
# [CV 5/5] END .....C=1, coef0=0.001, gamma=auto;, score=-0.193 total time=   0.0s
# [CV 1/5] END .....C=1, coef0=0.001, gamma=scale;, score=0.369 total time=   0.0s
# [CV 2/5] END .....C=1, coef0=0.001, gamma=scale;, score=0.272 total time=   0.0s
# [CV 3/5] END .....C=1, coef0=0.001, gamma=scale;, score=0.338 total time=   0.0s
# [CV 4/5] END .....C=1, coef0=0.001, gamma=scale;, score=0.370 total time=   0.0s
# [CV 5/5] END .....C=1, coef0=0.001, gamma=scale;, score=0.367 total time=   0.0s
# [CV 1/5] END ......C=1, coef0=0.01, gamma=auto;, score=-0.201 total time=   0.0s
# [CV 2/5] END ......C=1, coef0=0.01, gamma=auto;, score=-0.285 total time=   0.0s
# [CV 3/5] END ......C=1, coef0=0.01, gamma=auto;, score=-0.215 total time=   0.0s
# [CV 4/5] END ......C=1, coef0=0.01, gamma=auto;, score=-0.171 total time=   0.0s
# [CV 5/5] END ......C=1, coef0=0.01, gamma=auto;, score=-0.193 total time=   0.0s
# [CV 1/5] END ......C=1, coef0=0.01, gamma=scale;, score=0.369 total time=   0.0s
# [CV 2/5] END ......C=1, coef0=0.01, gamma=scale;, score=0.272 total time=   0.0s
# [CV 3/5] END ......C=1, coef0=0.01, gamma=scale;, score=0.338 total time=   0.0s
# [CV 4/5] END ......C=1, coef0=0.01, gamma=scale;, score=0.370 total time=   0.0s
# [CV 5/5] END ......C=1, coef0=0.01, gamma=scale;, score=0.367 total time=   0.0s
# [CV 1/5] END ........C=1, coef0=10, gamma=auto;, score=-0.201 total time=   0.0s
# [CV 2/5] END ........C=1, coef0=10, gamma=auto;, score=-0.285 total time=   0.0s
# [CV 3/5] END ........C=1, coef0=10, gamma=auto;, score=-0.215 total time=   0.0s
# [CV 4/5] END ........C=1, coef0=10, gamma=auto;, score=-0.171 total time=   0.0s
# [CV 5/5] END ........C=1, coef0=10, gamma=auto;, score=-0.193 total time=   0.0s
# [CV 1/5] END ........C=1, coef0=10, gamma=scale;, score=0.369 total time=   0.0s
# [CV 2/5] END ........C=1, coef0=10, gamma=scale;, score=0.272 total time=   0.0s
# [CV 3/5] END ........C=1, coef0=10, gamma=scale;, score=0.338 total time=   0.0s
# [CV 4/5] END ........C=1, coef0=10, gamma=scale;, score=0.370 total time=   0.0s
# [CV 5/5] END ........C=1, coef0=10, gamma=scale;, score=0.367 total time=   0.0s
# [CV 1/5] END .......C=1, coef0=0.5, gamma=auto;, score=-0.201 total time=   0.0s
# [CV 2/5] END .......C=1, coef0=0.5, gamma=auto;, score=-0.285 total time=   0.0s
# [CV 3/5] END .......C=1, coef0=0.5, gamma=auto;, score=-0.215 total time=   0.0s
# [CV 4/5] END .......C=1, coef0=0.5, gamma=auto;, score=-0.171 total time=   0.0s
# [CV 5/5] END .......C=1, coef0=0.5, gamma=auto;, score=-0.193 total time=   0.0s
# [CV 1/5] END .......C=1, coef0=0.5, gamma=scale;, score=0.369 total time=   0.0s
# [CV 2/5] END .......C=1, coef0=0.5, gamma=scale;, score=0.272 total time=   0.0s
# [CV 3/5] END .......C=1, coef0=0.5, gamma=scale;, score=0.338 total time=   0.0s
# [CV 4/5] END .......C=1, coef0=0.5, gamma=scale;, score=0.370 total time=   0.0s
# [CV 5/5] END .......C=1, coef0=0.5, gamma=scale;, score=0.367 total time=   0.0s
# [CV 1/5] END .....C=5, coef0=0.001, gamma=auto;, score=-0.169 total time=   0.0s
# [CV 2/5] END .....C=5, coef0=0.001, gamma=auto;, score=-0.259 total time=   0.0s
# [CV 3/5] END .....C=5, coef0=0.001, gamma=auto;, score=-0.191 total time=   0.0s
# [CV 4/5] END .....C=5, coef0=0.001, gamma=auto;, score=-0.125 total time=   0.0s
# [CV 5/5] END .....C=5, coef0=0.001, gamma=auto;, score=-0.141 total time=   0.0s
# [CV 1/5] END .....C=5, coef0=0.001, gamma=scale;, score=0.600 total time=   0.0s
# [CV 2/5] END .....C=5, coef0=0.001, gamma=scale;, score=0.504 total time=   0.0s
# [CV 3/5] END .....C=5, coef0=0.001, gamma=scale;, score=0.548 total time=   0.0s
# [CV 4/5] END .....C=5, coef0=0.001, gamma=scale;, score=0.549 total time=   0.0s
# [CV 5/5] END .....C=5, coef0=0.001, gamma=scale;, score=0.485 total time=   0.0s
# [CV 1/5] END ......C=5, coef0=0.01, gamma=auto;, score=-0.169 total time=   0.0s
# [CV 2/5] END ......C=5, coef0=0.01, gamma=auto;, score=-0.259 total time=   0.0s
# [CV 3/5] END ......C=5, coef0=0.01, gamma=auto;, score=-0.191 total time=   0.0s
# [CV 4/5] END ......C=5, coef0=0.01, gamma=auto;, score=-0.125 total time=   0.0s
# [CV 5/5] END ......C=5, coef0=0.01, gamma=auto;, score=-0.141 total time=   0.1s
# [CV 1/5] END ......C=5, coef0=0.01, gamma=scale;, score=0.600 total time=   0.0s
# [CV 2/5] END ......C=5, coef0=0.01, gamma=scale;, score=0.504 total time=   0.0s
# [CV 3/5] END ......C=5, coef0=0.01, gamma=scale;, score=0.548 total time=   0.0s
# [CV 4/5] END ......C=5, coef0=0.01, gamma=scale;, score=0.549 total time=   0.0s
# [CV 5/5] END ......C=5, coef0=0.01, gamma=scale;, score=0.485 total time=   0.0s
# [CV 1/5] END ........C=5, coef0=10, gamma=auto;, score=-0.169 total time=   0.0s
# [CV 2/5] END ........C=5, coef0=10, gamma=auto;, score=-0.259 total time=   0.0s
# [CV 3/5] END ........C=5, coef0=10, gamma=auto;, score=-0.191 total time=   0.0s
# [CV 4/5] END ........C=5, coef0=10, gamma=auto;, score=-0.125 total time=   0.0s
# [CV 5/5] END ........C=5, coef0=10, gamma=auto;, score=-0.141 total time=   0.0s
# [CV 1/5] END ........C=5, coef0=10, gamma=scale;, score=0.600 total time=   0.0s
# [CV 2/5] END ........C=5, coef0=10, gamma=scale;, score=0.504 total time=   0.0s
# [CV 3/5] END ........C=5, coef0=10, gamma=scale;, score=0.548 total time=   0.0s
# [CV 4/5] END ........C=5, coef0=10, gamma=scale;, score=0.549 total time=   0.0s
# [CV 5/5] END ........C=5, coef0=10, gamma=scale;, score=0.485 total time=   0.0s
# [CV 1/5] END .......C=5, coef0=0.5, gamma=auto;, score=-0.169 total time=   0.0s
# [CV 2/5] END .......C=5, coef0=0.5, gamma=auto;, score=-0.259 total time=   0.0s
# [CV 3/5] END .......C=5, coef0=0.5, gamma=auto;, score=-0.191 total time=   0.0s
# [CV 4/5] END .......C=5, coef0=0.5, gamma=auto;, score=-0.125 total time=   0.0s
# [CV 5/5] END .......C=5, coef0=0.5, gamma=auto;, score=-0.141 total time=   0.0s
# [CV 1/5] END .......C=5, coef0=0.5, gamma=scale;, score=0.600 total time=   0.0s
# [CV 2/5] END .......C=5, coef0=0.5, gamma=scale;, score=0.504 total time=   0.0s
# [CV 3/5] END .......C=5, coef0=0.5, gamma=scale;, score=0.548 total time=   0.0s
# [CV 4/5] END .......C=5, coef0=0.5, gamma=scale;, score=0.549 total time=   0.0s
# [CV 5/5] END .......C=5, coef0=0.5, gamma=scale;, score=0.485 total time=   0.0s
# [CV 1/5] END ....C=10, coef0=0.001, gamma=auto;, score=-0.116 total time=   0.0s
# [CV 2/5] END ....C=10, coef0=0.001, gamma=auto;, score=-0.208 total time=   0.0s
# [CV 3/5] END ....C=10, coef0=0.001, gamma=auto;, score=-0.139 total time=   0.0s
# [CV 4/5] END ....C=10, coef0=0.001, gamma=auto;, score=-0.072 total time=   0.0s
# [CV 5/5] END ....C=10, coef0=0.001, gamma=auto;, score=-0.072 total time=   0.0s
# [CV 1/5] END ....C=10, coef0=0.001, gamma=scale;, score=0.628 total time=   0.0s
# [CV 2/5] END ....C=10, coef0=0.001, gamma=scale;, score=0.533 total time=   0.0s
# [CV 3/5] END ....C=10, coef0=0.001, gamma=scale;, score=0.566 total time=   0.0s
# [CV 4/5] END ....C=10, coef0=0.001, gamma=scale;, score=0.567 total time=   0.0s
# [CV 5/5] END ....C=10, coef0=0.001, gamma=scale;, score=0.475 total time=   0.0s
# [CV 1/5] END .....C=10, coef0=0.01, gamma=auto;, score=-0.116 total time=   0.0s
# [CV 2/5] END .....C=10, coef0=0.01, gamma=auto;, score=-0.208 total time=   0.0s
# [CV 3/5] END .....C=10, coef0=0.01, gamma=auto;, score=-0.139 total time=   0.0s
# [CV 4/5] END .....C=10, coef0=0.01, gamma=auto;, score=-0.072 total time=   0.1s
# [CV 5/5] END .....C=10, coef0=0.01, gamma=auto;, score=-0.072 total time=   0.0s
# [CV 1/5] END .....C=10, coef0=0.01, gamma=scale;, score=0.628 total time=   0.0s
# [CV 2/5] END .....C=10, coef0=0.01, gamma=scale;, score=0.533 total time=   0.0s
# [CV 3/5] END .....C=10, coef0=0.01, gamma=scale;, score=0.566 total time=   0.0s
# [CV 4/5] END .....C=10, coef0=0.01, gamma=scale;, score=0.567 total time=   0.0s
# [CV 5/5] END .....C=10, coef0=0.01, gamma=scale;, score=0.475 total time=   0.0s
# [CV 1/5] END .......C=10, coef0=10, gamma=auto;, score=-0.116 total time=   0.1s
# [CV 2/5] END .......C=10, coef0=10, gamma=auto;, score=-0.208 total time=   0.1s
# [CV 3/5] END .......C=10, coef0=10, gamma=auto;, score=-0.139 total time=   0.0s
# [CV 4/5] END .......C=10, coef0=10, gamma=auto;, score=-0.072 total time=   0.0s
# [CV 5/5] END .......C=10, coef0=10, gamma=auto;, score=-0.072 total time=   0.0s
# [CV 1/5] END .......C=10, coef0=10, gamma=scale;, score=0.628 total time=   0.0s
# [CV 2/5] END .......C=10, coef0=10, gamma=scale;, score=0.533 total time=   0.0s
# [CV 3/5] END .......C=10, coef0=10, gamma=scale;, score=0.566 total time=   0.0s
# [CV 4/5] END .......C=10, coef0=10, gamma=scale;, score=0.567 total time=   0.0s
# [CV 5/5] END .......C=10, coef0=10, gamma=scale;, score=0.475 total time=   0.0s
# [CV 1/5] END ......C=10, coef0=0.5, gamma=auto;, score=-0.116 total time=   0.0s
# [CV 2/5] END ......C=10, coef0=0.5, gamma=auto;, score=-0.208 total time=   0.0s
# [CV 3/5] END ......C=10, coef0=0.5, gamma=auto;, score=-0.139 total time=   0.0s
# [CV 4/5] END ......C=10, coef0=0.5, gamma=auto;, score=-0.072 total time=   0.0s
# [CV 5/5] END ......C=10, coef0=0.5, gamma=auto;, score=-0.072 total time=   0.0s
# [CV 1/5] END ......C=10, coef0=0.5, gamma=scale;, score=0.628 total time=   0.0s
# [CV 2/5] END ......C=10, coef0=0.5, gamma=scale;, score=0.533 total time=   0.0s
# [CV 3/5] END ......C=10, coef0=0.5, gamma=scale;, score=0.566 total time=   0.0s
# [CV 4/5] END ......C=10, coef0=0.5, gamma=scale;, score=0.567 total time=   0.0s
# [CV 5/5] END ......C=10, coef0=0.5, gamma=scale;, score=0.475 total time=   0.0s
# [CV 1/5] END ....C=20, coef0=0.001, gamma=auto;, score=-0.029 total time=   0.0s
# [CV 2/5] END ....C=20, coef0=0.001, gamma=auto;, score=-0.119 total time=   0.1s
# [CV 3/5] END ....C=20, coef0=0.001, gamma=auto;, score=-0.038 total time=   0.1s
# [CV 4/5] END ....C=20, coef0=0.001, gamma=auto;, score=-0.009 total time=   0.0s
# [CV 5/5] END .....C=20, coef0=0.001, gamma=auto;, score=0.021 total time=   0.0s
# [CV 1/5] END ....C=20, coef0=0.001, gamma=scale;, score=0.641 total time=   0.0s
# [CV 2/5] END ....C=20, coef0=0.001, gamma=scale;, score=0.547 total time=   0.0s
# [CV 3/5] END ....C=20, coef0=0.001, gamma=scale;, score=0.574 total time=   0.0s
# [CV 4/5] END ....C=20, coef0=0.001, gamma=scale;, score=0.573 total time=   0.0s
# [CV 5/5] END ....C=20, coef0=0.001, gamma=scale;, score=0.461 total time=   0.0s
# [CV 1/5] END .....C=20, coef0=0.01, gamma=auto;, score=-0.029 total time=   0.0s
# [CV 2/5] END .....C=20, coef0=0.01, gamma=auto;, score=-0.119 total time=   0.1s
# [CV 3/5] END .....C=20, coef0=0.01, gamma=auto;, score=-0.038 total time=   0.0s
# [CV 4/5] END .....C=20, coef0=0.01, gamma=auto;, score=-0.009 total time=   0.0s
# [CV 5/5] END ......C=20, coef0=0.01, gamma=auto;, score=0.021 total time=   0.0s
# [CV 1/5] END .....C=20, coef0=0.01, gamma=scale;, score=0.641 total time=   0.0s
# [CV 2/5] END .....C=20, coef0=0.01, gamma=scale;, score=0.547 total time=   0.0s
# [CV 3/5] END .....C=20, coef0=0.01, gamma=scale;, score=0.574 total time=   0.0s
# [CV 4/5] END .....C=20, coef0=0.01, gamma=scale;, score=0.573 total time=   0.0s
# [CV 5/5] END .....C=20, coef0=0.01, gamma=scale;, score=0.461 total time=   0.0s
# [CV 1/5] END .......C=20, coef0=10, gamma=auto;, score=-0.029 total time=   0.0s
# [CV 2/5] END .......C=20, coef0=10, gamma=auto;, score=-0.119 total time=   0.0s
# [CV 3/5] END .......C=20, coef0=10, gamma=auto;, score=-0.038 total time=   0.0s
# [CV 4/5] END .......C=20, coef0=10, gamma=auto;, score=-0.009 total time=   0.0s
# [CV 5/5] END ........C=20, coef0=10, gamma=auto;, score=0.021 total time=   0.0s
# [CV 1/5] END .......C=20, coef0=10, gamma=scale;, score=0.641 total time=   0.0s
# [CV 2/5] END .......C=20, coef0=10, gamma=scale;, score=0.547 total time=   0.0s
# [CV 3/5] END .......C=20, coef0=10, gamma=scale;, score=0.574 total time=   0.0s
# [CV 4/5] END .......C=20, coef0=10, gamma=scale;, score=0.573 total time=   0.0s
# [CV 5/5] END .......C=20, coef0=10, gamma=scale;, score=0.461 total time=   0.0s
# [CV 1/5] END ......C=20, coef0=0.5, gamma=auto;, score=-0.029 total time=   0.0s
# [CV 2/5] END ......C=20, coef0=0.5, gamma=auto;, score=-0.119 total time=   0.0s
# [CV 3/5] END ......C=20, coef0=0.5, gamma=auto;, score=-0.038 total time=   0.0s
# [CV 4/5] END ......C=20, coef0=0.5, gamma=auto;, score=-0.009 total time=   0.0s
# [CV 5/5] END .......C=20, coef0=0.5, gamma=auto;, score=0.021 total time=   0.0s
# [CV 1/5] END ......C=20, coef0=0.5, gamma=scale;, score=0.641 total time=   0.0s
# [CV 2/5] END ......C=20, coef0=0.5, gamma=scale;, score=0.547 total time=   0.0s
# [CV 3/5] END ......C=20, coef0=0.5, gamma=scale;, score=0.574 total time=   0.0s
# [CV 4/5] END ......C=20, coef0=0.5, gamma=scale;, score=0.573 total time=   0.0s
# [CV 5/5] END ......C=20, coef0=0.5, gamma=scale;, score=0.461 total time=   0.0s
# [CV 1/5] END .....C=50, coef0=0.001, gamma=auto;, score=0.151 total time=   0.0s
# [CV 2/5] END .....C=50, coef0=0.001, gamma=auto;, score=0.102 total time=   0.0s
# [CV 3/5] END .....C=50, coef0=0.001, gamma=auto;, score=0.185 total time=   0.0s
# [CV 4/5] END .....C=50, coef0=0.001, gamma=auto;, score=0.181 total time=   0.0s
# [CV 5/5] END .....C=50, coef0=0.001, gamma=auto;, score=0.245 total time=   0.0s
# [CV 1/5] END ....C=50, coef0=0.001, gamma=scale;, score=0.647 total time=   0.0s
# [CV 2/5] END ....C=50, coef0=0.001, gamma=scale;, score=0.545 total time=   0.0s
# [CV 3/5] END ....C=50, coef0=0.001, gamma=scale;, score=0.576 total time=   0.0s
# [CV 4/5] END ....C=50, coef0=0.001, gamma=scale;, score=0.576 total time=   0.0s
# [CV 5/5] END ....C=50, coef0=0.001, gamma=scale;, score=0.445 total time=   0.0s
# [CV 1/5] END ......C=50, coef0=0.01, gamma=auto;, score=0.151 total time=   0.0s
# [CV 2/5] END ......C=50, coef0=0.01, gamma=auto;, score=0.102 total time=   0.0s
# [CV 3/5] END ......C=50, coef0=0.01, gamma=auto;, score=0.185 total time=   0.0s
# [CV 4/5] END ......C=50, coef0=0.01, gamma=auto;, score=0.181 total time=   0.0s
# [CV 5/5] END ......C=50, coef0=0.01, gamma=auto;, score=0.245 total time=   0.1s
# [CV 1/5] END .....C=50, coef0=0.01, gamma=scale;, score=0.647 total time=   0.0s
# [CV 2/5] END .....C=50, coef0=0.01, gamma=scale;, score=0.545 total time=   0.0s
# [CV 3/5] END .....C=50, coef0=0.01, gamma=scale;, score=0.576 total time=   0.0s
# [CV 4/5] END .....C=50, coef0=0.01, gamma=scale;, score=0.576 total time=   0.0s
# [CV 5/5] END .....C=50, coef0=0.01, gamma=scale;, score=0.445 total time=   0.0s
# [CV 1/5] END ........C=50, coef0=10, gamma=auto;, score=0.151 total time=   0.0s
# [CV 2/5] END ........C=50, coef0=10, gamma=auto;, score=0.102 total time=   0.0s
# [CV 3/5] END ........C=50, coef0=10, gamma=auto;, score=0.185 total time=   0.0s
# [CV 4/5] END ........C=50, coef0=10, gamma=auto;, score=0.181 total time=   0.0s
# [CV 5/5] END ........C=50, coef0=10, gamma=auto;, score=0.245 total time=   0.0s
# [CV 1/5] END .......C=50, coef0=10, gamma=scale;, score=0.647 total time=   0.0s
# [CV 2/5] END .......C=50, coef0=10, gamma=scale;, score=0.545 total time=   0.0s
# [CV 3/5] END .......C=50, coef0=10, gamma=scale;, score=0.576 total time=   0.0s
# [CV 4/5] END .......C=50, coef0=10, gamma=scale;, score=0.576 total time=   0.0s
# [CV 5/5] END .......C=50, coef0=10, gamma=scale;, score=0.445 total time=   0.0s
# [CV 1/5] END .......C=50, coef0=0.5, gamma=auto;, score=0.151 total time=   0.1s
# [CV 2/5] END .......C=50, coef0=0.5, gamma=auto;, score=0.102 total time=   0.1s
# [CV 3/5] END .......C=50, coef0=0.5, gamma=auto;, score=0.185 total time=   0.1s
# [CV 4/5] END .......C=50, coef0=0.5, gamma=auto;, score=0.181 total time=   0.1s
# [CV 5/5] END .......C=50, coef0=0.5, gamma=auto;, score=0.245 total time=   0.1s
# [CV 1/5] END ......C=50, coef0=0.5, gamma=scale;, score=0.647 total time=   0.0s
# [CV 2/5] END ......C=50, coef0=0.5, gamma=scale;, score=0.545 total time=   0.0s
# [CV 3/5] END ......C=50, coef0=0.5, gamma=scale;, score=0.576 total time=   0.0s
# [CV 4/5] END ......C=50, coef0=0.5, gamma=scale;, score=0.576 total time=   0.0s
# [CV 5/5] END ......C=50, coef0=0.5, gamma=scale;, score=0.445 total time=   0.0s
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [1, 5, 10, 20, 50],
#                          'coef0': [0.001, 0.01, 10, 0.5],
#                          'gamma': ('auto', 'scale')},
#              verbose=3)

# %%
print(gs.best_params_)
gpred = gs.predict(X_test)
# Out:
# {'C': 20, 'coef0': 0.001, 'gamma': 'scale'}

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error

# %%
print(mean_absolute_error(y_test, gpred))
print(mean_squared_error(y_test, gpred))
print(root_mean_squared_error(y_test, gpred))
# Out:
# 30.220542317055013
# 2145.9489267893805
# 46.324388034699176

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(n_estimators=1000)

# %%
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=1000)

# %%
rfr.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 1000,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
pred = rfr.predict(X_test)

# %%
print(mean_absolute_error(y_test, pred))
print(mean_squared_error(y_test, pred))
print(root_mean_squared_error(y_test, pred))
# Out:
# 20.984181818181817
# 1312.1316930129872
# 36.22335838948381

# %%
ydf = pd.DataFrame(y_test, dtype=float)
ydf['Preds'] = pred
ydf['diff'] = abs(ydf['Catch Rate'] - ydf['Preds'])
ydf[:30]
# Out:
#      Catch Rate    Preds    diff
# 90         60.0   49.738  10.262
# 295       180.0  180.538   0.538
# 572        60.0   75.583  15.583
# 382         3.0    3.421   0.421
# 939       180.0  236.665  56.665
# 239        45.0   85.216  40.216
# 584       190.0  181.420   8.580
# 274        45.0   54.609   9.609
# 912        45.0   45.427   0.427
# 20        255.0  249.305   5.695
# 677        75.0   75.210   0.210
# 618       180.0  148.895  31.105
# 611        45.0   39.190   5.810
# 772         3.0    4.651   1.651
# 263        90.0  132.692  42.692
# 443        45.0   74.360  29.360
# 375         3.0   35.048  32.048
# 361        75.0   68.437   6.563
# 42        255.0  213.550  41.450
# 752       190.0  205.080  15.080
# 41         90.0   76.972  13.028
# 208       190.0  202.820  12.820
# 630        90.0   64.570  25.430
# 460        45.0   50.048   5.048
# 492         3.0   10.341   7.341
# 737        45.0   44.455   0.545
# 620        45.0   65.322  20.322
# 687       120.0  197.235  77.235
# 685       190.0  221.915  31.915
# 141        45.0   44.588   0.412

# %%
#Random Forest Regressor has much better performance compared to SVR
